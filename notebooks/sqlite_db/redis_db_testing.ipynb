# %%
import os
import re
import string
import numpy as np

import msgpack
import msgpack_numpy as m
m.patch()

import redis
import pandas as pd
from nltk.corpus import stopwords

import cleantext

from sklearn.metrics.pairwise import cosine_similarity

import warnings
warnings.filterwarnings('ignore')

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import tensorflow as tf
import tensorflow_text
import tensorflow_hub as hub

# %%
df_xlm = pd.read_pickle('final_dataframe.pkl')
df_xlm = df_xlm[['id', 'text', 'lang', 'title', 'pubDate', 'label', 'text_len']]
df_xlm.sample(2)
# Out:
#                       id                                               text  \
# 6616  210705_news_415060  Consensus is Harder Than It Looks And it looks...
# 806   210705_news_258006  BT has reported a near-70% surge in customers ...
#
#      lang                                              title  \
# 6616   en           Consensus Is Harder Than It Looks (2020)
# 806    en  Working from home fuels surge in BT sign-ups f...
#
#                  pubDate  label  text_len
# 6616 2021-02-09 10:03:48      1      1277
# 806  2020-07-31 12:59:25      1       337

# %%
len(df_xlm.index)
# Out:
# 26954

# %%
final_df = pd.read_pickle(os.getcwd()+'/../dataframes/quantum_rank_df.pkl')
final_df.head(2)
# Out:
#                    id               query  ranking_label  \
# 0   210705_news_53540  Quantentechnologie              3
# 1  210705_news_509066  Quantentechnologie              2
#
#                                                 text  text_len lang  \
# 0  Nach Cyberangriffen auf den Bundestag und das ...       445   de
# 1  The following is the May 24, 2021 Congressiona...       506   en
#
#                                          text_tokens  \
# 0  [Cyberangriffe, der Bundestag, der Datennetzwe...
# 1  [the following, the May 24, 2021 Congressional...
#
#                                               nc_vec  label  label_name  \
# 0  [[-0.01808716543018818, -0.0072739748284220695...      1  technology
# 1  [[-0.009140371344983578, -0.002850867807865143...      1  technology
#
#                                                title             pubDate  \
# 0  Netze deutscher Ministerien: Quantenkommunikat... 2019-12-16 10:26:15
# 1  Report on Military Applications for Quantum Co... 2021-05-27 14:12:00
#
#                                                  url
# 0  https://www.spiegel.de/netzwelt/netzpolitik/qu...
# 1  https://news.usni.org/2021/05/27/report-on-mil...

# %%
tf_model = hub.load(os.getcwd()+ '/../../models/USE_model')

# %%
# custom_pipeline = [preprocessing.fillna,
#                    preprocessing.remove_html_tags,
#                    preprocessing.remove_urls,
#                    preprocessing.remove_digits,
#                    preprocessing.remove_whitespace,
#                   ]

def get_clean_text(text):
    
    clean_text = cleantext.clean(text,
            clean_all= False, # Execute all cleaning operations
            extra_spaces=True ,  # Remove extra white spaces 
            )
    
    clean_text = re.sub(r'http\S+', '', clean_text)
    p = re.compile(r'<.*?>')
    return p.sub('', clean_text)

final_df['text_clean'] = final_df.apply(lambda x:get_clean_text(x['text']), axis=1)

# %%
final_df[['text', 'text_clean']]
# Out:
#                                                  text  \
# 0   Nach Cyberangriffen auf den Bundestag und das ...
# 1   The following is the May 24, 2021 Congressiona...
# 2   \n        No previous knowledge of quantum phy...
# 3   Grundsätzlich haben Quantencomputer das Potenz...
# 4   Amazon Braket is a fully managed quantum compu...
# 5   Quantencomputer versprechen, bestimmte Klassen...
# 6   Die ETH Zürich und das Paul Scherrer Institut ...
# 7   In seiner mehr als 100-jährigen Geschichte hat...
# 8   Der rheinland-pfälzische Pharmakonzern Boehrin...
# 9   Intel stellt Qubits für den Quantencomputer de...
# 10  Deutschland soll im Wettlauf zwischen US-Konze...
# 11  Die Eigenschaften elektronisch nulldimensional...
# 12  NASHUA, N.H. -  Until the 21st Century, artifi...
# 13  Amazon Braket is a fully managed quantum compu...
# 14  Im internationalen Wettlauf um die Technik der...
# 15  Eine quantensichere Verbindung zweier Behörden...
# 16  Hightech aus Ulm für den Weltraum: Das neue In...
# 17  IBM führt eine Zertifizierung für Quantencompu...
# 18  Am Leibniz-Rechenzentrum (LRZ) in Garching wur...
# 19  Eine von der Bundesregierung eingesetzte Exper...
# 20  This post describes how to use text mining to ...
# 21  Ein Forscherteam von QuTech in den Niederlande...
# 22  In der IT-Sicherheit werden Quantencomputer hä...
# 23  Das Bundesamt für Sicherheit in der Informatio...
#
#                                            text_clean
# 0   Nach Cyberangriffen auf den Bundestag und das ...
# 1   The following is the May 24, 2021 Congressiona...
# 2   No previous knowledge of quantum physics is re...
# 3   Grundsätzlich haben Quantencomputer das Potenz...
# 4   Amazon Braket is a fully managed quantum compu...
# 5   Quantencomputer versprechen, bestimmte Klassen...
# 6   Die ETH Zürich und das Paul Scherrer Institut ...
# 7   In seiner mehr als 100-jährigen Geschichte hat...
# 8   Der rheinland-pfälzische Pharmakonzern Boehrin...
# 9   Intel stellt Qubits für den Quantencomputer de...
# 10  Deutschland soll im Wettlauf zwischen US-Konze...
# 11  Die Eigenschaften elektronisch nulldimensional...
# 12  NASHUA, N.H. - Until the 21st Century, artific...
# 13  Amazon Braket is a fully managed quantum compu...
# 14  Im internationalen Wettlauf um die Technik der...
# 15  Eine quantensichere Verbindung zweier Behörden...
# 16  Hightech aus Ulm für den Weltraum: Das neue In...
# 17  IBM führt eine Zertifizierung für Quantencompu...
# 18  Am Leibniz-Rechenzentrum (LRZ) in Garching wur...
# 19  Eine von der Bundesregierung eingesetzte Exper...
# 20  This post describes how to use text mining to ...
# 21  Ein Forscherteam von QuTech in den Niederlande...
# 22  In der IT-Sicherheit werden Quantencomputer hä...
# 23  Das Bundesamt für Sicherheit in der Informatio...

# %%
stopwords_de = stopwords.words('german')
stopwords_en = stopwords.words('english')

stopwords_full = []
stopwords_full.extend(stopwords_de)
stopwords_full.extend(stopwords_en)

stopwords_full = [word.lower() for word in stopwords_full]

stop_all = set(stopwords_full + list(string.punctuation))

# %%
def get_modified_vectors(vec_data):
    
    new_data = []
    for val in vec_data:
        new_data.append(val)
    
    new_data = np.array(new_data).reshape(-1, 512)
    return new_data

def get_pool_vec(doc_vec_list, pool):
    
    doc_vec_list = get_modified_vectors(doc_vec_list)
    if pool == 'mean':
        return np.nanmean(doc_vec_list, axis=0)
    elif pool == 'max':
        return np.nanmax(doc_vec_list, axis=0)

def get_document_vec(text):
    
    return tf_model(text)['outputs'].numpy()[0].reshape(1, -1)

def get_representation_vector(document, title):
    
    title_vec = get_document_vec(title)
    
    document_tokens = document.split()
    doc_len = len(document_tokens)
    doc_vecs = []
    
    doc_vecs.append(title_vec)
    
    if doc_len < 550:
        doc_vecs.append(get_document_vec(document))
    else:
        doc_parts = int(doc_len/500)
        for idx in range(doc_parts):
            if (idx+1)*500 >= doc_len:
                doc_temp = ' '.join(document_tokens[idx*500:])
            else:
                doc_temp = ' '.join(document_tokens[idx*500:(idx+1)*500])
                
            doc_vecs.append(get_document_vec(doc_temp))
        
    return get_pool_vec(get_modified_vectors(doc_vecs), pool='mean')

def get_shorter_text(phrase_1, phrase_2):
    
    if len(phrase_1) < len(phrase_2):
        return phrase_1
    else:
        return phrase_2
    
def remove_stopwords(noun_chunks):
    
    filtered_noun_chunks = []
    
    for word_token in noun_chunks:
        if word_token.lower() not in stop_all:
            filtered_noun_chunks.append(word_token)
            
    return filtered_noun_chunks

def get_filtered_nc(noun_chunks):
    
    noun_chunks = list(set(noun_chunks))
    noun_chunks = remove_stopwords(noun_chunks)
    phrases_len = len(noun_chunks)
    remove_phrases = [] 

    for idx_1 in range(phrases_len):

        phrase_1 = noun_chunks[idx_1]
        for idx_2 in range(idx_1 + 1, phrases_len):
            phrase_2 = noun_chunks[idx_2]

            if fuzz.ratio(phrase_1, phrase_2) > 80:
                remove_phrases.append(get_shorter_text(phrase_1, phrase_2))

    final_noun_chunks = list(set(noun_chunks) - set(remove_phrases))
    return final_noun_chunks

def get_sent_transformers_keywords(repr_vec, noun_chunks, max_keyword_cnt = 30):
    
    noun_chunks = get_filtered_nc(noun_chunks)
    candidate_embeddings = [tf_model(nc)['outputs'].numpy()[0] for nc in noun_chunks]
    
    kw_distances = cosine_similarity([repr_vec], candidate_embeddings)
    
    data_insert_dict = dict()
    keywords_dict = dict()
    for index in kw_distances.argsort()[0][-max_keyword_cnt:]: 
        
        data_insert_dict[noun_chunks[index]] =  m.packb(candidate_embeddings[index])
                
        keywords_dict[noun_chunks[index]] = kw_distances[0][index]
        
    rdb.mset(data_insert_dict)
        
    return keywords_dict

# %%
final_df['doc_repr_vec'] = final_df.apply(lambda x:get_representation_vector(x['text_clean'], x['title']), axis=1)

# %%
final_df['keywords'] = final_df.apply(lambda x:get_sent_transformers_keywords(x['doc_repr_vec'], x['text_tokens'], max_keyword_cnt = 30), axis=1)

# %%
m.unpackb(rdb.get('QuNet'))
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in get_connection(self, command_name, *keys, **options)
#    1392             try:
# -> 1393                 if connection.can_read():
#    1394                     raise ConnectionError("Connection has data")
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in can_read(self, timeout)
#     808         try:
# --> 809             return self._parser.can_read(timeout)
#     810         except OSError as e:
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in can_read(self, timeout)
#     314     def can_read(self, timeout):
# --> 315         return self._buffer and self._buffer.can_read(timeout)
#     316
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in can_read(self, timeout)
#     222         return bool(self.length) or self._read_from_socket(
# --> 223             timeout=timeout, raise_on_timeout=False
#     224         )
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in _read_from_socket(self, length, timeout, raise_on_timeout)
#     194                 if isinstance(data, bytes) and len(data) == 0:
# --> 195                     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
#     196                 buf.write(data)
#
# ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in connect(self)
#     611             sock = self.retry.call_with_retry(
# --> 612                 lambda: self._connect(), lambda error: self.disconnect(error)
#     613             )
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\retry.py in call_with_retry(self, do, fail)
#      45             try:
# ---> 46                 return do()
#      47             except self._supported_errors as error:
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in <lambda>()
#     611             sock = self.retry.call_with_retry(
# --> 612                 lambda: self._connect(), lambda error: self.disconnect(error)
#     613             )
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in _connect(self)
#     676         if err is not None:
# --> 677             raise err
#     678         raise OSError("socket.getaddrinfo returned an empty list")
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in _connect(self)
#     664                 # connect
# --> 665                 sock.connect(socket_address)
#     666
#
# ConnectionRefusedError: [WinError 10061] Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15960\952530705.py in <module>
# ----> 1 m.unpackb(rdb.get('QuNet'))
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\commands\core.py in get(self, name)
#    1703         For more information see https://redis.io/commands/get
#    1704         """
# -> 1705         return self.execute_command("GET", name)
#    1706
#    1707     def getdel(self, name: KeyT) -> ResponseT:
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\client.py in execute_command(self, *args, **options)
#    1233         pool = self.connection_pool
#    1234         command_name = args[0]
# -> 1235         conn = self.connection or pool.get_connection(command_name, **options)
#    1236
#    1237         try:
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in get_connection(self, command_name, *keys, **options)
#    1395             except (ConnectionError, OSError):
#    1396                 connection.disconnect()
# -> 1397                 connection.connect()
#    1398                 if connection.can_read():
#    1399                     raise ConnectionError("Connection not ready")
#
# ~\.virtualenvs\xxx-eAHl9Gue\lib\site-packages\redis\connection.py in connect(self)
#     615             raise TimeoutError("Timeout connecting to server")
#     616         except OSError as e:
# --> 617             raise ConnectionError(self._error_message(e))
#     618
#     619         self._sock = sock
#
# ConnectionError: Error 10061 connecting to host.docker.internal:6379. Es konnte keine Verbindung hergestellt werden, da der Zielcomputer die Verbindung verweigerte.

# %%
for idx, row in final_df.iterrows():
    
    print(row['id'])
    rdb.set(row['id'], m.packb(row['doc_repr_vec']))
# Out:
# 210705_news_53540
# 210705_news_509066
# 210705_news_339270
# 210705_news_285448
# 210705_news_40840
# 210705_news_269414
# 210705_news_488902
# 210705_news_304057
# 210705_news_387878
# 210705_news_158828
# 210705_news_91745
# 210705_news_376449
# 210705_news_280755
# 210705_news_274384
# 210705_news_494243
# 210705_news_357644
# 210705_news_509162
# 210705_news_464796
# 210705_news_449895
# 210705_news_392072
# 210705_news_160641
# 210705_news_471982
# 210705_news_289800
# 210705_news_139039

# %%
rdb = redis.StrictRedis(
    host='host.docker.internal',
    port=6379,
#     db=0,
#     username='xxx',
#     password='mit22yyy!'
)

rdb.set('France', 'Paris')
# Out:
# True

# %%
rdb.get('France')
# Out:
# b'Paris'
