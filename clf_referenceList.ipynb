# %%
import os
import pandas as pd
import numpy as np
from collections import Counter
import spacy

import fasttext
import fasttext.util

from sklearn.metrics import precision_recall_fscore_support, classification_report
from sklearn.metrics.pairwise import cosine_similarity

import tensorflow as tf
import tensorflow_text

import warnings; warnings.simplefilter('ignore')

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
tf.saved_model.LoadOptions(
    allow_partial_checkpoint=False,
    experimental_io_device='/job:localhost',
    experimental_skip_checkpoint=False
)

tf_model = tf.keras.models.load_model(
    os.getcwd() + '/models/USE_model/'
)
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.

# %%
topic_list = ['Wirtschaft und Finanzen', 'Bildung', 'Politik', 'Tierreich', 'Rechtswissenschaften und Rechtsprechung', 'Gesundheit', 'Automobilbranche', 'Unterhaltung', 'Sport', 'Werbung',  'Innovation', 'Innovation und Technologie', 'Technologie', 'Smartphone', 'iPhone', 'Bitcoin']

topic_embeddings_dict = dict()
for topic in topic_list:
    topic_embeddings_dict[topic] = tf_model(topic)['outputs'].numpy()[0].reshape(1, -1)

# %%
def get_use_topic_score(doc_vec, topic):
    
    return cosine_similarity(doc_vec, topic_embeddings_dict[topic])[0][0]

# %%
vec_list = embeddings['outputs'].numpy()

# %%
cosine_similarity(vec_list[0].reshape(1, -1), vec_list[1].reshape(1, -1))[0][0]
# Out:
# 0.83537215

# %%
model_path = os.getcwd() + '/models/cc.de.300.bin'
fasttext_model = fasttext.load_model(model_path)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
w1 = 'bauen'
w2 = 'einbauen'
w3 = 'aufbauen'
w4 = 'verbauen'

vec_1 = fasttext_model.get_word_vector(w1).reshape(1, -1)
vec_2 = fasttext_model.get_word_vector(w2).reshape(1, -1)
vec_3 = fasttext_model.get_word_vector(w3).reshape(1, -1)
vec_4 = fasttext_model.get_word_vector(w4).reshape(1, -1)

print(f'{w1} -- {w2} {cosine_similarity(vec_1, vec_2)[0][0]}')
print(f'{w1} -- {w3} {cosine_similarity(vec_1, vec_3)[0][0]}')
print(f'{w1} -- {w4} {cosine_similarity(vec_1, vec_4)[0][0]}')
# Out:
# bauen -- einbauen 0.632020115852356
# bauen -- aufbauen 0.7113096714019775
# bauen -- verbauen 0.6564719676971436

# %%
def dateien_lesen(pfad):
    files = os.listdir(pfad)
    text_list = []
    for file_name in files:
        f = open(pfad + "/" + file_name, 'r', encoding="utf8")
        text_list.append(f.read())
        f.close()
    return text_list

# %%
pfad_inno = os.getcwd() + "/Innovation"
pfad_neg = os.getcwd() + "/negative"

pfad_test = os.getcwd() + "/test"

# %%
text_list_inno = dateien_lesen(pfad_inno)
text_list_neg = dateien_lesen(pfad_neg)

text_list_test = dateien_lesen(pfad_test)

# %%
inno_dict_as_set = set()
for docm in text_list_inno:
    for token in docm.split():
        if not token[0].isupper():
            inno_dict_as_set.add(token)

# %%
neg_dict_as_set = set()
for docm in text_list_neg:
    for token in docm.split():
        if not token[0].isupper():
            neg_dict_as_set.add(token)

# %%
nlp = spacy.load("de_core_news_sm")

# %%
def get_verb_adj_data(doc_list):
    
    va_list = []
    for docm in doc_list:
        sublist = []
        for token in nlp(docm):
            if token.pos_ in ["VERB", "ADJ"]:
                sublist.append(token.lemma_)
        va_list.append((Counter(sublist), len(docm.split())))
        
    return va_list

def get_verb_adj_score(doc_list, va_list, reference_list, label):
    
    count1=0
    score_sets = []

    for i, obj in enumerate(va_list):
        points = 0
        for ref_term in reference_list:
            if ref_term in obj[0].keys():
                points = points + obj[0][ref_term]

        score_sets.append((doc_list[i],label, points, points/obj[1]))
    
    return score_sets

# %%
va_list1 = get_verb_adj_data(text_list_inno)
va_list2 = get_verb_adj_data(text_list_neg)
va_list3 = get_verb_adj_data(text_list_test)

# %%
# va_list1

# %%
def is_doc_unrelated(score, threshold=0.4):
    if score > threshold:
        return 1
    return 0

def get_f1score_threshold(preds, gt, threshold):
    
    relevancy_list = []

    for score in preds:
        rel = is_doc_unrelated(score, threshold)
        relevancy_list.append(rel)
        
#     print(classification_report(gt, relevancy_list))
    
    total_correct = 0
    for pred, cor in zip(relevancy_list, gt):
        if cor == 1 and pred == 1:
            total_correct += 1
    
    return total_correct, precision_recall_fscore_support(gt, relevancy_list)[2][1]

def get_best_f1_score(preds, gt):
    
    threshold_vals = np.arange(0.0, 0.02, 0.0001)
    f1_scores_list = []
    max_threshold = None

    for val in threshold_vals:
        val = round(val, 2)
        relevancy_list = []

        for score in preds:
            rel = is_doc_unrelated(score, threshold=val)
            relevancy_list.append(rel)

        f1_scores_list.append(precision_recall_fscore_support(gt, relevancy_list)[2][1])
    
    max_f1score = max(f1_scores_list)
    max_threshold = threshold_vals[f1_scores_list.index(max_f1score)]
    
    return max_threshold, max(f1_scores_list)

# %%
reference_list = [
    #"installieren",
    #"kompilieren",
    "künstlich",
    "automatisch",
    "automatisieren",
    "hochautomatisiert",
    "konfigurierbar"
    "experimentell",
    #"fahrerlos",
    "intelligent",
    #"smart",
    "entwickeln",
    #"synthetisieren",
    "lösen",
    "energiesparend",
    "energiefressend",
    "mathematisch",
    #"mechanisch",
    #"neuronal",
    "umbauen",
    #"digital",
    "digitalisieren",
    "zukünftig",
    "innovativ",
    "technisch",
    "autonom",
    "detektieren",
    "energetisch",
    "evaluieren",
    "erkennen",
    "experimentieren",
    "verbessern",
    "portabel",
#     "portieren",
    "programmieren",
    "technologisch",
    "softwaredefiniert",
    "softwaregestützt",
    #"spektral",
    #"spezifisch",
    "trainiert",
    "serviceorientiert",
    #"adaptiv"
]

# %%
reference_list_2 = [
    'analysieren',
    'erforschen',
    'identifizieren',
    'erforschen',
    'beobachten',
    'aufspüren',
    'hervorheben',
    'betonen',
    'bewerten',
    'beeinflussen',
    'feststellen',
    'beweisen',
    'rechtfertigen',
    'nachprüfen',
    'fortschreiten',
    'entwickeln',
    'weiterentwickeln',
    'übertreffen',
    'steigern',
    'maximieren',
    'transformieren',
    'umwandeln',
    'approximieren',
    'schätzen',
    'begründen',
    'illustrieren',
    'vorhersagen',
    'validieren',
    'reproduzieren',
    'erkennen',
    'klassifizieren',
    'reklamieren',
    'auflösen',
    'formulieren',
    'forschen',
    'untersuchen',
    'integrieren',
    'interpolieren',
    'empfehlen',
    'anzeigen',
    'interpretieren',
    'aufzeigen',
    'ableiten',
    'erklären',
    'gestalten',
    'erfinden',
    'entdecken',
    'modernisieren',
    'revolutionieren',
    'entscheidend',
    'bedeutend', 
    'aufbauen',
    'ermitteln',
    'erreichen',
    'berichten',
    'optimieren'
]
# reference_list = list(set(reference_list+reference_list_2))

# %%
innovation_score_sets = get_verb_adj_score(text_list_inno, va_list1, reference_list, 1)
negative_score_sets = get_verb_adj_score(text_list_neg, va_list2, reference_list, 0)

test_score_sets = get_verb_adj_score(text_list_test, va_list3, reference_list, 1)

# %%
train_documents = innovation_score_sets + negative_score_sets

# %%
doc_df = pd.DataFrame(train_documents, columns=["document_text", "label", "tf_score", "tf_score_weighted"])
doc_df.sample(2)
# Out:
#                                          document_text  label  tf_score  \
# 381  \n\t\t\t\t\t Microsofts Betriebssystem Windows...      0         2
# 962  Trotz noblem Tagungsort direkt an der Potsdame...      0         1
#
#      tf_score_weighted
# 381           0.001854
# 962           0.001214

# %%
doc_df_test = pd.DataFrame(test_score_sets, columns=["document_text", "label", "tf_score", "tf_score_weighted"])

# %%
doc_df_pos = doc_df[doc_df['label'] == 1]
doc_df_neg = doc_df[doc_df['label'] == 0]

doc_df_pos = doc_df_pos.sort_values(by=['tf_score_weighted'], ascending=False)
doc_df_neg = doc_df_neg.sort_values(by=['tf_score_weighted'], ascending=False)
# doc_df_test = doc_df_test.sort_values(by=['tf_score_weighted'], ascending=False)

np.savetxt(os.getcwd()+"/output/positive_tf_scores.txt", doc_df_pos.tf_score_weighted.values, delimiter=",", fmt='%f')
np.savetxt(os.getcwd()+"/output/negative_tf_scores.txt", doc_df_neg.tf_score_weighted.values, delimiter=",", fmt='%f')
# np.savetxt(os.getcwd()+"/output/test_tf_scores.txt", doc_df_test.tf_score_weighted.values, delimiter=",", fmt='%f')

# %%
# threshold, f1_score = get_best_f1_score(doc_df['tf_score_weighted'].values, doc_df['label'].values)
threshold = 0.0021

# %%
get_f1score_threshold(doc_df['tf_score_weighted'].values, doc_df['label'].values, threshold)
# Out:
# (29, 0.058232931726907626)

# %%
get_f1score_threshold(doc_df_test['tf_score_weighted'].values, doc_df_test['label'].values, threshold)
# Out:
# (18, 0.6206896551724138)

# %%
# Verb Score approach
# threshold: 0.002107
# neg: 260 out of 1426
# pos: 24 out of 30

# USE Score approach
# threshold: 0.046012
# neg: 180 out of 1426
# pos: 21 out of 30

# threshold: 0.0051
# f1-score: 0.327

# test 40 docs
# 12 out of 40

# %%
doc_df['doc_vec'] = doc_df.apply(lambda x:tf_model(x['document_text'])['outputs'].numpy()[0].reshape(1, -1), axis=1)

# %%
for topic in topic_list:
    topic_col_name = topic.lower().replace(' ', '_') + '_sim'
    doc_df[topic_col_name] = doc_df.apply(lambda x:get_use_topic_score(x['doc_vec'], topic), axis=1)
    
doc_df.columns
# Out:
# Index(['document_text', 'label', 'tf_score', 'tf_score_weighted', 'doc_vec',
#        'wirtschaft_und_finanzen_sim', 'bildung_sim', 'politik_sim',
#        'tierreich_sim', 'rechtswissenschaften_und_rechtsprechung_sim',
#        'gesundheit_sim', 'automobilbranche_sim', 'unterhaltung_sim',
#        'sport_sim', 'werbung_sim', 'innovation_sim',
#        'innovation_und_technologie_sim', 'technologie_sim', 'smartphone_sim',
#        'hybrid_score', 'iphone_sim', 'bitcoin_sim'],
#       dtype='object')

# %%
def get_hybrid_score(a, b, c, d, l, e, f):
    
    if c >= min(a,b) or (a<0 and b<0) or d>b or (e)>0.2 or f>0.1:
        return 0
#     if d >= b:
#         return 0
#     if d>b:
    print(f'l: {l}, a: {round(a, 2)}, b: {round(b, 2)}, c: {round(c, 2)}, d: {round(d, 2)}, e: {round(e, 2)}, f: {round(f, 2)}')
    
    if c>0:
        return b
    else:
        return a+b-c

# doc_df['hybrid_score'] = doc_df.apply(lambda x:get_hybrid_score(x['innovation_sim'], x['technologie_sim'], max(x['wirtschaft_und_finanzen_sim'], x['bildung_sim'], x['politik_sim'],x['tierreich_sim'], x['rechtswissenschaften_und_rechtsprechung_sim'],x['gesundheit_sim'], x['automobilbranche_sim'], x['unterhaltung_sim'],x['sport_sim'], x['werbung_sim'], x['anzeige_sim'])), axis=1)
doc_df['hybrid_score'] = doc_df.apply(lambda x:get_hybrid_score(x['innovation_sim'], x['technologie_sim'], x['werbung_sim'], x['smartphone_sim'], x['label'], x['wirtschaft_und_finanzen_sim'] + x['bitcoin_sim'], x['iphone_sim']), axis=1)
doc_df['label'].corr(doc_df['hybrid_score'])
# Out:
# l: 1, a: 0.03, b: 0.08, c: 0.02, d: 0.04, e: 0.06, f: -0.09
# l: 1, a: 0.09, b: 0.05, c: -0.0, d: 0.02, e: -0.03, f: -0.06
# l: 1, a: -0.0, b: 0.0, c: -0.04, d: -0.05, e: -0.02, f: -0.06
# l: 1, a: 0.08, b: 0.04, c: -0.02, d: 0.01, e: -0.01, f: -0.03
# l: 1, a: -0.03, b: 0.07, c: -0.04, d: -0.02, e: 0.14, f: -0.02
# l: 1, a: 0.02, b: 0.01, c: 0.0, d: -0.03, e: -0.08, f: -0.1
# l: 1, a: 0.05, b: 0.1, c: -0.08, d: -0.04, e: 0.02, f: -0.06
# l: 1, a: 0.04, b: 0.09, c: -0.03, d: 0.02, e: 0.04, f: -0.02
# l: 1, a: 0.02, b: 0.05, c: -0.03, d: 0.03, e: -0.05, f: -0.02
# l: 1, a: 0.08, b: 0.03, c: -0.0, d: -0.02, e: 0.18, f: -0.03
# l: 1, a: 0.09, b: 0.02, c: -0.04, d: -0.02, e: -0.03, f: -0.06
# l: 1, a: -0.02, b: 0.1, c: -0.05, d: -0.03, e: 0.06, f: -0.04
# l: 1, a: 0.03, b: 0.12, c: -0.04, d: 0.03, e: 0.06, f: -0.02
# l: 0, a: 0.01, b: 0.01, c: -0.01, d: -0.01, e: -0.04, f: -0.04
# l: 0, a: 0.04, b: 0.04, c: 0.02, d: 0.02, e: 0.07, f: -0.01
# l: 0, a: 0.03, b: 0.06, c: -0.02, d: -0.07, e: 0.04, f: 0.02
# l: 0, a: -0.03, b: 0.05, c: -0.05, d: -0.05, e: 0.02, f: -0.11
# 0.2823849253285573

# %%
doc_df_pos = doc_df[doc_df['label'] == 1]
doc_df_neg = doc_df[doc_df['label'] == 0]

doc_df_pos = doc_df_pos.sort_values(by=['hybrid_score'], ascending=False)
doc_df_neg = doc_df_neg.sort_values(by=['hybrid_score'], ascending=False)
# doc_df_test = doc_df_test.sort_values(by=['tf_score_weighted'], ascending=False)

np.savetxt(os.getcwd()+"/output/positive_innovation_sim_scores.txt", doc_df_pos.hybrid_score.values, delimiter=",", fmt='%f')
np.savetxt(os.getcwd()+"/output/negative_innovation_sim_scores.txt", doc_df_neg.hybrid_score.values, delimiter=",", fmt='%f')
# np.savetxt(os.getcwd()+"/output/test_tf_scores.txt", doc_df_test.tf_score_weighted.values, delimiter=",", fmt='%f')

# %%
doc_df['label'].corr(doc_df['tf_score_weighted'])
# Out:
# 0.1982997247242723

# %%
for idx, row in doc_df_neg.iterrows():
    
    if row['hybrid_score'] > 0.1 and row['hybrid_score'] < 0.2:
        print(row)
        
        print('\n\n')
# Out:
# document_text                                  Micron hat einen Käufer für das Halbleiterwerk...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.07143805, -0.0164167, 0.027678376, 0.01744...
# wirtschaft_und_finanzen_sim                                                             0.024937
# bildung_sim                                                                            -0.032584
# politik_sim                                                                            -0.061248
# tierreich_sim                                                                          -0.016644
# rechtswissenschaften_und_rechtsprechung_sim                                             0.004191
# gesundheit_sim                                                                         -0.024693
# automobilbranche_sim                                                                    0.008957
# unterhaltung_sim                                                                        0.029005
# sport_sim                                                                              -0.037079
# werbung_sim                                                                            -0.034394
# innovation_sim                                                                          0.045586
# innovation_und_technologie_sim                                                            0.1079
# technologie_sim                                                                         0.108512
# smartphone_sim                                                                         -0.020422
# hybrid_score                                                                            0.188492
# iphone_sim                                                                             -0.065686
# bitcoin_sim                                                                              0.07906
# Name: 779, dtype: object
#
#
#
# document_text                                  \n                   Tesla-Boss mit überrasche...
# label                                                                                          0
# tf_score                                                                                       3
# tf_score_weighted                                                                       0.005455
# doc_vec                                        [[0.053646263, -0.12270827, -0.069456, 0.00476...
# wirtschaft_und_finanzen_sim                                                              0.08579
# bildung_sim                                                                            -0.006452
# politik_sim                                                                            -0.040163
# tierreich_sim                                                                          -0.001865
# rechtswissenschaften_und_rechtsprechung_sim                                             0.045119
# gesundheit_sim                                                                         -0.017185
# automobilbranche_sim                                                                   -0.033939
# unterhaltung_sim                                                                        0.036606
# sport_sim                                                                              -0.011587
# werbung_sim                                                                             -0.01748
# innovation_sim                                                                          0.065138
# innovation_und_technologie_sim                                                          0.117122
# technologie_sim                                                                         0.105647
# smartphone_sim                                                                         -0.014711
# hybrid_score                                                                            0.188265
# iphone_sim                                                                              0.002377
# bitcoin_sim                                                                             0.198588
# Name: 564, dtype: object
#
#
#
# document_text                                  Apple baut offenbar ein Spezialteam rund um Sa...
# label                                                                                          0
# tf_score                                                                                       4
# tf_score_weighted                                                                       0.013289
# doc_vec                                        [[0.014486053, 0.025339684, 0.055552177, 0.030...
# wirtschaft_und_finanzen_sim                                                            -0.000772
# bildung_sim                                                                            -0.071116
# politik_sim                                                                            -0.050902
# tierreich_sim                                                                          -0.044127
# rechtswissenschaften_und_rechtsprechung_sim                                             0.011262
# gesundheit_sim                                                                          -0.05665
# automobilbranche_sim                                                                   -0.055003
# unterhaltung_sim                                                                       -0.012296
# sport_sim                                                                              -0.024106
# werbung_sim                                                                            -0.044855
# innovation_sim                                                                          0.057073
# innovation_und_technologie_sim                                                          0.114194
# technologie_sim                                                                         0.086153
# smartphone_sim                                                                          0.085512
# hybrid_score                                                                            0.188081
# iphone_sim                                                                              0.226524
# bitcoin_sim                                                                             0.040129
# Name: 970, dtype: object
#
#
#
# document_text                                  Den Blick durch entsprechende Trendstudien in ...
# label                                                                                          0
# tf_score                                                                                       2
# tf_score_weighted                                                                       0.009804
# doc_vec                                        [[0.0023038038, 0.03862448, 0.051077176, 0.019...
# wirtschaft_und_finanzen_sim                                                              -0.0374
# bildung_sim                                                                              0.00447
# politik_sim                                                                             0.029395
# tierreich_sim                                                                          -0.001404
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.002387
# gesundheit_sim                                                                         -0.029074
# automobilbranche_sim                                                                   -0.080334
# unterhaltung_sim                                                                       -0.004155
# sport_sim                                                                               0.001677
# werbung_sim                                                                            -0.055509
# innovation_sim                                                                          0.040713
# innovation_und_technologie_sim                                                           0.09789
# technologie_sim                                                                          0.08816
# smartphone_sim                                                                          0.005412
# hybrid_score                                                                            0.184382
# iphone_sim                                                                             -0.049763
# bitcoin_sim                                                                             0.020889
# Name: 708, dtype: object
#
#
#
# document_text                                  Wie der Nachrichtensender "Bloomberg" berichte...
# label                                                                                          0
# tf_score                                                                                       1
# tf_score_weighted                                                                       0.004367
# doc_vec                                        [[-0.032793075, -0.024048718, -0.016898008, 0....
# wirtschaft_und_finanzen_sim                                                             0.042158
# bildung_sim                                                                            -0.019334
# politik_sim                                                                            -0.028968
# tierreich_sim                                                                           -0.02455
# rechtswissenschaften_und_rechtsprechung_sim                                             0.021143
# gesundheit_sim                                                                         -0.012531
# automobilbranche_sim                                                                    0.006929
# unterhaltung_sim                                                                        0.005947
# sport_sim                                                                               0.043958
# werbung_sim                                                                            -0.013469
# innovation_sim                                                                          0.077895
# innovation_und_technologie_sim                                                          0.105072
# technologie_sim                                                                         0.085593
# smartphone_sim                                                                          0.033677
# hybrid_score                                                                            0.176958
# iphone_sim                                                                              0.067381
# bitcoin_sim                                                                             0.030337
# Name: 1346, dtype: object
#
#
#
# document_text                                  Spitzenverbände der Wirtschaft sehen die Arbei...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.07393562, -0.022023153, -0.011089691, 0.00...
# wirtschaft_und_finanzen_sim                                                             0.048591
# bildung_sim                                                                             0.125847
# politik_sim                                                                            -0.002096
# tierreich_sim                                                                           0.037767
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.042099
# gesundheit_sim                                                                         -0.007607
# automobilbranche_sim                                                                    0.006404
# unterhaltung_sim                                                                       -0.050425
# sport_sim                                                                               0.011415
# werbung_sim                                                                            -0.009145
# innovation_sim                                                                          0.100565
# innovation_und_technologie_sim                                                          0.084872
# technologie_sim                                                                         0.066008
# smartphone_sim                                                                          0.014318
# hybrid_score                                                                            0.175718
# iphone_sim                                                                             -0.045204
# bitcoin_sim                                                                             0.052322
# Name: 1139, dtype: object
#
#
#
# document_text                                  Die DuMont-Mediengruppe verkauft den Berliner ...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-0.046234604, -0.044378754, 0.07364452, 0.01...
# wirtschaft_und_finanzen_sim                                                            -0.040721
# bildung_sim                                                                            -0.019241
# politik_sim                                                                            -0.027362
# tierreich_sim                                                                          -0.019401
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.024516
# gesundheit_sim                                                                          0.015477
# automobilbranche_sim                                                                    0.010566
# unterhaltung_sim                                                                       -0.021994
# sport_sim                                                                               0.023959
# werbung_sim                                                                            -0.010791
# innovation_sim                                                                          0.045261
# innovation_und_technologie_sim                                                          0.093743
# technologie_sim                                                                         0.114471
# smartphone_sim                                                                          0.001035
# hybrid_score                                                                            0.170523
# iphone_sim                                                                              0.046158
# bitcoin_sim                                                                             0.036096
# Name: 273, dtype: object
#
#
#
# document_text                                  Für Administratoren bleibt in den nächsten Jah...
# label                                                                                          0
# tf_score                                                                                       2
# tf_score_weighted                                                                       0.011364
# doc_vec                                        [[0.06588446, 0.0153348455, 0.021231886, 0.022...
# wirtschaft_und_finanzen_sim                                                             0.017311
# bildung_sim                                                                            -0.013208
# politik_sim                                                                             0.004727
# tierreich_sim                                                                           0.006252
# rechtswissenschaften_und_rechtsprechung_sim                                             0.026201
# gesundheit_sim                                                                         -0.043022
# automobilbranche_sim                                                                   -0.032281
# unterhaltung_sim                                                                       -0.034289
# sport_sim                                                                              -0.006523
# werbung_sim                                                                            -0.090243
# innovation_sim                                                                          0.019653
# innovation_und_technologie_sim                                                          0.059945
# technologie_sim                                                                         0.060488
# smartphone_sim                                                                         -0.016777
# hybrid_score                                                                            0.170384
# iphone_sim                                                                             -0.040572
# bitcoin_sim                                                                            -0.006862
# Name: 771, dtype: object
#
#
#
# document_text                                  Volkswagen   -Miteigner Wolfgang  Porsche  sch...
# label                                                                                          0
# tf_score                                                                                       1
# tf_score_weighted                                                                       0.005848
# doc_vec                                        [[0.04771688, -0.07829302, -0.054044925, 0.042...
# wirtschaft_und_finanzen_sim                                                             0.043082
# bildung_sim                                                                            -0.053976
# politik_sim                                                                            -0.035456
# tierreich_sim                                                                          -0.029747
# rechtswissenschaften_und_rechtsprechung_sim                                             0.058451
# gesundheit_sim                                                                          -0.02661
# automobilbranche_sim                                                                    0.143174
# unterhaltung_sim                                                                       -0.036479
# sport_sim                                                                               0.009926
# werbung_sim                                                                            -0.071741
# innovation_sim                                                                           0.05343
# innovation_und_technologie_sim                                                          0.086049
# technologie_sim                                                                         0.039573
# smartphone_sim                                                                         -0.009812
# hybrid_score                                                                            0.164744
# iphone_sim                                                                              0.003732
# bitcoin_sim                                                                            -0.044604
# Name: 182, dtype: object
#
#
#
# document_text                                  Wieder ist ein NATO-Gipfel glimpflich abgelauf...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-0.026671767, 0.051771235, 0.024421394, -0.0...
# wirtschaft_und_finanzen_sim                                                             -0.02782
# bildung_sim                                                                            -0.014713
# politik_sim                                                                            -0.026532
# tierreich_sim                                                                           -0.00165
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.048127
# gesundheit_sim                                                                          0.022599
# automobilbranche_sim                                                                   -0.065372
# unterhaltung_sim                                                                        0.040844
# sport_sim                                                                               0.053385
# werbung_sim                                                                            -0.024603
# innovation_sim                                                                          0.080714
# innovation_und_technologie_sim                                                          0.096396
# technologie_sim                                                                         0.059091
# smartphone_sim                                                                          0.009962
# hybrid_score                                                                            0.164408
# iphone_sim                                                                             -0.018784
# bitcoin_sim                                                                             0.015831
# Name: 1183, dtype: object
#
#
#
# document_text                                  „Daher will auch Brandenburg, dass dieses Werk...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.005237078, -0.05187642, -0.025929889, 0.06...
# wirtschaft_und_finanzen_sim                                                             0.018955
# bildung_sim                                                                            -0.025598
# politik_sim                                                                            -0.045052
# tierreich_sim                                                                          -0.020241
# rechtswissenschaften_und_rechtsprechung_sim                                             0.004307
# gesundheit_sim                                                                          0.004896
# automobilbranche_sim                                                                    0.049854
# unterhaltung_sim                                                                       -0.010785
# sport_sim                                                                                0.00014
# werbung_sim                                                                            -0.039674
# innovation_sim                                                                          0.060576
# innovation_und_technologie_sim                                                          0.088745
# technologie_sim                                                                         0.060496
# smartphone_sim                                                                         -0.021158
# hybrid_score                                                                            0.160746
# iphone_sim                                                                             -0.037511
# bitcoin_sim                                                                            -0.000403
# Name: 846, dtype: object
#
#
#
# document_text                                  Egal ob mit dem E-Scooter, Fahrrad oder auf de...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.0041064583, 0.02320577, -0.035169307, 0.01...
# wirtschaft_und_finanzen_sim                                                             0.051741
# bildung_sim                                                                             0.022535
# politik_sim                                                                             0.025572
# tierreich_sim                                                                          -0.026541
# rechtswissenschaften_und_rechtsprechung_sim                                             0.029587
# gesundheit_sim                                                                          0.046509
# automobilbranche_sim                                                                    0.051929
# unterhaltung_sim                                                                        0.015827
# sport_sim                                                                               0.074635
# werbung_sim                                                                            -0.001229
# innovation_sim                                                                          0.083217
# innovation_und_technologie_sim                                                          0.120754
# technologie_sim                                                                         0.074503
# smartphone_sim                                                                            0.0517
# hybrid_score                                                                            0.158948
# iphone_sim                                                                              0.113681
# bitcoin_sim                                                                             0.000806
# Name: 1098, dtype: object
#
#
#
# document_text                                  \n                   Messenger-Innovation: Neu...
# label                                                                                          0
# tf_score                                                                                       1
# tf_score_weighted                                                                       0.001664
# doc_vec                                        [[-0.01650097, -0.034619592, -0.041062757, 0.0...
# wirtschaft_und_finanzen_sim                                                             0.016766
# bildung_sim                                                                            -0.018978
# politik_sim                                                                             0.006724
# tierreich_sim                                                                           0.008572
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.010109
# gesundheit_sim                                                                         -0.040451
# automobilbranche_sim                                                                   -0.052514
# unterhaltung_sim                                                                        0.010027
# sport_sim                                                                               -0.03172
# werbung_sim                                                                            -0.033378
# innovation_sim                                                                          0.060882
# innovation_und_technologie_sim                                                          0.114661
# technologie_sim                                                                         0.064151
# smartphone_sim                                                                          0.056973
# hybrid_score                                                                             0.15841
# iphone_sim                                                                              0.036576
# bitcoin_sim                                                                             0.035281
# Name: 1059, dtype: object
#
#
#
# document_text                                  "Multi-Stakeholder" klingt nach Mist. Und was ...
# label                                                                                          0
# tf_score                                                                                       2
# tf_score_weighted                                                                       0.006309
# doc_vec                                        [[-0.003871817, -0.025190506, 0.04950381, -0.0...
# wirtschaft_und_finanzen_sim                                                            -0.053484
# bildung_sim                                                                            -0.045846
# politik_sim                                                                             0.039761
# tierreich_sim                                                                          -0.018646
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.001025
# gesundheit_sim                                                                         -0.079493
# automobilbranche_sim                                                                   -0.048495
# unterhaltung_sim                                                                       -0.010085
# sport_sim                                                                               0.022417
# werbung_sim                                                                            -0.046791
# innovation_sim                                                                          0.060006
# innovation_und_technologie_sim                                                          0.081849
# technologie_sim                                                                         0.050554
# smartphone_sim                                                                         -0.058822
# hybrid_score                                                                            0.157352
# iphone_sim                                                                             -0.106787
# bitcoin_sim                                                                             0.024168
# Name: 1092, dtype: object
#
#
#
# document_text                                  \n    Protecting the nation's warfighters and ...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-0.001069068, 0.03716685, 0.04974424, 0.0418...
# wirtschaft_und_finanzen_sim                                                             -0.00451
# bildung_sim                                                                             0.006428
# politik_sim                                                                            -0.011588
# tierreich_sim                                                                          -0.028157
# rechtswissenschaften_und_rechtsprechung_sim                                             0.005829
# gesundheit_sim                                                                          0.022649
# automobilbranche_sim                                                                   -0.046631
# unterhaltung_sim                                                                        0.034102
# sport_sim                                                                               0.046868
# werbung_sim                                                                            -0.040364
# innovation_sim                                                                          0.020445
# innovation_und_technologie_sim                                                          0.060586
# technologie_sim                                                                         0.096191
# smartphone_sim                                                                          0.010607
# hybrid_score                                                                               0.157
# iphone_sim                                                                              -0.02405
# bitcoin_sim                                                                             0.007556
# Name: 879, dtype: object
#
#
#
# document_text                                  \n        Der Bitcoin übersprang am Dienstag w...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.016164891, -0.13336642, 0.002682677, 0.033...
# wirtschaft_und_finanzen_sim                                                             0.173083
# bildung_sim                                                                             0.003123
# politik_sim                                                                             0.001583
# tierreich_sim                                                                          -0.014727
# rechtswissenschaften_und_rechtsprechung_sim                                             0.116988
# gesundheit_sim                                                                          -0.05763
# automobilbranche_sim                                                                   -0.021724
# unterhaltung_sim                                                                        0.025176
# sport_sim                                                                              -0.016107
# werbung_sim                                                                            -0.069601
# innovation_sim                                                                         -0.003654
# innovation_und_technologie_sim                                                            0.0715
# technologie_sim                                                                         0.083305
# smartphone_sim                                                                         -0.001029
# hybrid_score                                                                            0.149253
# iphone_sim                                                                              0.027151
# bitcoin_sim                                                                             0.365168
# Name: 1232, dtype: object
#
#
#
# document_text                                  \n                   Auch Tesla dabei: Kindera...
# label                                                                                          0
# tf_score                                                                                       2
# tf_score_weighted                                                                       0.005222
# doc_vec                                        [[0.023648892, -0.02276453, -0.013059039, 0.04...
# wirtschaft_und_finanzen_sim                                                            -0.060431
# bildung_sim                                                                            -0.033349
# politik_sim                                                                            -0.049327
# tierreich_sim                                                                           -0.02549
# rechtswissenschaften_und_rechtsprechung_sim                                             0.038584
# gesundheit_sim                                                                          -0.01701
# automobilbranche_sim                                                                    0.039096
# unterhaltung_sim                                                                        0.006677
# sport_sim                                                                              -0.014486
# werbung_sim                                                                            -0.060334
# innovation_sim                                                                          0.018136
# innovation_und_technologie_sim                                                          0.070615
# technologie_sim                                                                         0.067304
# smartphone_sim                                                                         -0.025255
# hybrid_score                                                                            0.145775
# iphone_sim                                                                              -0.03029
# bitcoin_sim                                                                              0.00169
# Name: 887, dtype: object
#
#
#
# document_text                                  Auf Frankfurt am Main folgt nun Bad Homburg vo...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-0.047830008, 0.020403104, 0.09336544, 0.028...
# wirtschaft_und_finanzen_sim                                                            -0.057184
# bildung_sim                                                                            -0.061009
# politik_sim                                                                            -0.030826
# tierreich_sim                                                                           0.003484
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.064793
# gesundheit_sim                                                                          0.073127
# automobilbranche_sim                                                                   -0.064278
# unterhaltung_sim                                                                       -0.018212
# sport_sim                                                                               -0.00361
# werbung_sim                                                                            -0.057921
# innovation_sim                                                                         -0.011812
# innovation_und_technologie_sim                                                          0.038906
# technologie_sim                                                                         0.098391
# smartphone_sim                                                                          0.084364
# hybrid_score                                                                            0.144499
# iphone_sim                                                                               0.06478
# bitcoin_sim                                                                            -0.018174
# Name: 943, dtype: object
#
#
#
# document_text                                  Die Aufspaltung des schweizerischen Rüstungs- ...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.024909502, -0.0053055426, 0.10760297, 0.01...
# wirtschaft_und_finanzen_sim                                                            -0.035907
# bildung_sim                                                                             0.002757
# politik_sim                                                                            -0.025718
# tierreich_sim                                                                          -0.004175
# rechtswissenschaften_und_rechtsprechung_sim                                              0.00118
# gesundheit_sim                                                                         -0.029453
# automobilbranche_sim                                                                   -0.017571
# unterhaltung_sim                                                                        0.009562
# sport_sim                                                                               0.011755
# werbung_sim                                                                            -0.030228
# innovation_sim                                                                          0.089409
# innovation_und_technologie_sim                                                          0.094078
# technologie_sim                                                                         0.024245
# smartphone_sim                                                                         -0.029085
# hybrid_score                                                                            0.143881
# iphone_sim                                                                             -0.017354
# bitcoin_sim                                                                              0.00424
# Name: 52, dtype: object
#
#
#
# document_text                                  Brasilianische Behörden haben WhatsApp aufgefo...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-0.045427233, -7.093856e-05, 0.0849871, -0.0...
# wirtschaft_und_finanzen_sim                                                            -0.011585
# bildung_sim                                                                            -0.083941
# politik_sim                                                                             0.014282
# tierreich_sim                                                                           0.001684
# rechtswissenschaften_und_rechtsprechung_sim                                             0.037028
# gesundheit_sim                                                                         -0.029385
# automobilbranche_sim                                                                   -0.032657
# unterhaltung_sim                                                                        0.018165
# sport_sim                                                                               0.053365
# werbung_sim                                                                            -0.071533
# innovation_sim                                                                           0.01974
# innovation_und_technologie_sim                                                          0.078396
# technologie_sim                                                                         0.052383
# smartphone_sim                                                                          0.038928
# hybrid_score                                                                            0.143656
# iphone_sim                                                                             -0.013139
# bitcoin_sim                                                                             0.027937
# Name: 515, dtype: object
#
#
#
# document_text                                  Eine Datenbank mit Basisinformationen von mehr...
# label                                                                                          0
# tf_score                                                                                       4
# tf_score_weighted                                                                       0.014706
# doc_vec                                        [[-0.02335446, 0.071150385, 0.104014814, 0.006...
# wirtschaft_und_finanzen_sim                                                            -0.058375
# bildung_sim                                                                            -0.112683
# politik_sim                                                                             0.004787
# tierreich_sim                                                                          -0.018531
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.034036
# gesundheit_sim                                                                         -0.069319
# automobilbranche_sim                                                                      -0.059
# unterhaltung_sim                                                                       -0.047253
# sport_sim                                                                              -0.030151
# werbung_sim                                                                            -0.104396
# innovation_sim                                                                         -0.010997
# innovation_und_technologie_sim                                                          0.061527
# technologie_sim                                                                         0.041869
# smartphone_sim                                                                          0.007377
# hybrid_score                                                                            0.135269
# iphone_sim                                                                             -0.000784
# bitcoin_sim                                                                             0.033535
# Name: 964, dtype: object
#
#
#
# document_text                                  \n                   Nie wieder Akku-Probleme:...
# label                                                                                          0
# tf_score                                                                                       2
# tf_score_weighted                                                                       0.001727
# doc_vec                                        [[-0.04760746, 0.041343514, -0.02069317, -0.03...
# wirtschaft_und_finanzen_sim                                                             0.012917
# bildung_sim                                                                             0.018839
# politik_sim                                                                             0.025248
# tierreich_sim                                                                            0.02989
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.035581
# gesundheit_sim                                                                          0.004711
# automobilbranche_sim                                                                   -0.017832
# unterhaltung_sim                                                                        0.049561
# sport_sim                                                                               0.032717
# werbung_sim                                                                            -0.010636
# innovation_sim                                                                          0.037391
# innovation_und_technologie_sim                                                          0.069978
# technologie_sim                                                                         0.083656
# smartphone_sim                                                                           0.05588
# hybrid_score                                                                            0.131684
# iphone_sim                                                                              0.210912
# bitcoin_sim                                                                            -0.017244
# Name: 1040, dtype: object
#
#
#
# document_text                                  Die von Russland und China ausgehenden politis...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# ...
# werbung_sim                                                                             0.053105
# innovation_sim                                                                           0.09706
# innovation_und_technologie_sim                                                           0.18265
# technologie_sim                                                                         0.104131
# smartphone_sim                                                                          0.096982
# hybrid_score                                                                            0.104131
# iphone_sim                                                                               0.05296
# bitcoin_sim                                                                            -0.023878
# Name: 125, dtype: object
#
#
#
# document_text                                  Moderne verteilte Systeme gestalten sich immer...
# label                                                                                          0
# tf_score                                                                                       3
# tf_score_weighted                                                                       0.009554
# doc_vec                                        [[0.0058463584, -0.026923845, 0.07556004, -0.0...
# wirtschaft_und_finanzen_sim                                                            -0.021467
# bildung_sim                                                                            -0.125254
# politik_sim                                                                            -0.056482
# tierreich_sim                                                                          -0.026641
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.061748
# gesundheit_sim                                                                         -0.037081
# automobilbranche_sim                                                                    -0.01822
# unterhaltung_sim                                                                       -0.079412
# sport_sim                                                                              -0.041294
# werbung_sim                                                                            -0.085404
# innovation_sim                                                                         -0.002971
# innovation_und_technologie_sim                                                          0.020051
# technologie_sim                                                                         0.021606
# smartphone_sim                                                                         -0.035657
# hybrid_score                                                                            0.104039
# iphone_sim                                                                             -0.082783
# bitcoin_sim                                                                            -0.032605
# Name: 638, dtype: object
#
#
#
# document_text                                  Fahrerlose Autos sollen in  Deutschland  schon...
# label                                                                                          0
# tf_score                                                                                       6
# tf_score_weighted                                                                       0.018927
# doc_vec                                        [[0.0068690004, -0.048254985, 0.0744802, 0.045...
# wirtschaft_und_finanzen_sim                                                            -0.071349
# bildung_sim                                                                            -0.030625
# politik_sim                                                                             0.003118
# tierreich_sim                                                                           0.032722
# rechtswissenschaften_und_rechtsprechung_sim                                             0.023305
# gesundheit_sim                                                                         -0.041206
# automobilbranche_sim                                                                    0.167582
# unterhaltung_sim                                                                        0.015656
# sport_sim                                                                               0.033948
# werbung_sim                                                                            -0.037901
# innovation_sim                                                                          0.027925
# innovation_und_technologie_sim                                                           0.05873
# technologie_sim                                                                         0.037875
# smartphone_sim                                                                         -0.008674
# hybrid_score                                                                            0.103701
# iphone_sim                                                                             -0.080316
# bitcoin_sim                                                                            -0.057575
# Name: 693, dtype: object
#
#
#
# document_text                                  \n        Der Auto- und Lkw-Zulieferer ZF Frie...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-0.021875868, -0.05591827, 0.03467028, 0.049...
# wirtschaft_und_finanzen_sim                                                             0.000969
# bildung_sim                                                                             -0.05176
# politik_sim                                                                              0.00419
# tierreich_sim                                                                          -0.036522
# rechtswissenschaften_und_rechtsprechung_sim                                             -0.02261
# gesundheit_sim                                                                         -0.017984
# automobilbranche_sim                                                                    0.077331
# unterhaltung_sim                                                                        0.019583
# sport_sim                                                                               0.036068
# werbung_sim                                                                            -0.018984
# innovation_sim                                                                          0.033773
# innovation_und_technologie_sim                                                           0.06197
# technologie_sim                                                                         0.050041
# smartphone_sim                                                                         -0.011295
# hybrid_score                                                                            0.102797
# iphone_sim                                                                             -0.054879
# bitcoin_sim                                                                            -0.019269
# Name: 202, dtype: object
#
#
#
# document_text                                  Nach der öffentlichen Präsentation des niederl...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[0.0048753605, 0.012324772, 0.06448878, 0.044...
# wirtschaft_und_finanzen_sim                                                            -0.011157
# bildung_sim                                                                             0.020305
# politik_sim                                                                             0.004386
# tierreich_sim                                                                           0.024727
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.046377
# gesundheit_sim                                                                          0.001412
# automobilbranche_sim                                                                   -0.025327
# unterhaltung_sim                                                                        0.034227
# sport_sim                                                                               0.018444
# werbung_sim                                                                            -0.026301
# innovation_sim                                                                          0.040548
# innovation_und_technologie_sim                                                          0.042955
# technologie_sim                                                                         0.035323
# smartphone_sim                                                                          0.000642
# hybrid_score                                                                            0.102172
# iphone_sim                                                                             -0.044143
# bitcoin_sim                                                                             0.025772
# Name: 1143, dtype: object
#
#
#
# document_text                                  Paukenschlag in Walldorf: Der seit 2010 amtier...
# label                                                                                          0
# tf_score                                                                                       1
# tf_score_weighted                                                                       0.003215
# doc_vec                                        [[0.040099442, -0.034568537, 0.07229922, 0.019...
# wirtschaft_und_finanzen_sim                                                             0.042548
# bildung_sim                                                                            -0.045042
# politik_sim                                                                            -0.045209
# tierreich_sim                                                                          -0.009683
# rechtswissenschaften_und_rechtsprechung_sim                                             0.023756
# gesundheit_sim                                                                         -0.013356
# automobilbranche_sim                                                                   -0.027017
# unterhaltung_sim                                                                       -0.044126
# sport_sim                                                                               0.015102
# werbung_sim                                                                            -0.016641
# innovation_sim                                                                          0.044398
# innovation_und_technologie_sim                                                           0.06821
# technologie_sim                                                                         0.040572
# smartphone_sim                                                                         -0.040243
# hybrid_score                                                                            0.101611
# iphone_sim                                                                             -0.026906
# bitcoin_sim                                                                             0.010186
# Name: 900, dtype: object
#
#
#
# document_text                                  Der Bitcoin-Kurs hat für viele Anleger überras...
# label                                                                                          0
# tf_score                                                                                       0
# tf_score_weighted                                                                            0.0
# doc_vec                                        [[-2.4750667e-05, -0.13756095, 0.043304045, 0....
# wirtschaft_und_finanzen_sim                                                             0.123141
# bildung_sim                                                                             0.001461
# politik_sim                                                                             0.004451
# tierreich_sim                                                                          -0.010713
# rechtswissenschaften_und_rechtsprechung_sim                                             0.075683
# gesundheit_sim                                                                         -0.025757
# automobilbranche_sim                                                                   -0.042419
# unterhaltung_sim                                                                        0.019493
# sport_sim                                                                              -0.024953
# werbung_sim                                                                            -0.028207
# innovation_sim                                                                          0.028227
# innovation_und_technologie_sim                                                          0.064082
# technologie_sim                                                                         0.044789
# smartphone_sim                                                                         -0.026532
# hybrid_score                                                                            0.101223
# iphone_sim                                                                             -0.024104
# bitcoin_sim                                                                             0.264613
# Name: 463, dtype: object
#
#
#
# document_text                                  Im Ozean schwimmen enorme Mengen von schwer ab...
# label                                                                                          0
# tf_score                                                                                       1
# tf_score_weighted                                                                       0.002762
# doc_vec                                        [[-0.020222114, -0.020246655, -0.010606794, -0...
# wirtschaft_und_finanzen_sim                                                             0.033082
# bildung_sim                                                                             0.053057
# politik_sim                                                                             0.029884
# tierreich_sim                                                                            0.03591
# rechtswissenschaften_und_rechtsprechung_sim                                            -0.011171
# gesundheit_sim                                                                         -0.025286
# automobilbranche_sim                                                                   -0.020251
# unterhaltung_sim                                                                        0.026545
# sport_sim                                                                               0.042502
# werbung_sim                                                                            -0.031471
# innovation_sim                                                                         -0.025989
# innovation_und_technologie_sim                                                          0.058703
# technologie_sim                                                                         0.094824
# smartphone_sim                                                                         -0.071086
# hybrid_score                                                                            0.100306
# iphone_sim                                                                             -0.109776
# bitcoin_sim                                                                             0.045617
# Name: 679, dtype: object

# %%
doc_df.to_pickle(os.getcwd() + f'/notebooks/dataframes/verb_based_classifier.pkl')

# %%
doc_df = pd.read_pickle(os.getcwd() + f'/notebooks/dataframes/verb_based_classifier.pkl')
